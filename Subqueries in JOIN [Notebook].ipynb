# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Subquery in the JOIN clause

# %% [markdown]
# In this notebook we will look at subqueries, which are powerful tools to enable more in-depth analysis in SQL. They are essentially intermediate results sets that we access with another query, so **a query inside another query**. We can use subqueries in various places in a query, and those subquery results also have various forms. Here, we look at the **use of a subquery in the `JOIN` clause.**

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn:
# - How to use the result set of a subquery in the main query by joining the main table to the subquery on a related column.

# %% [markdown]
# ## Overview
#
# Imagine we want to calculate the percentage of land area that a specific country in a sub-region occupies, as a percentage of the total land area in that sub-region. We would need to divide each country’s land area with the sum of all countries in that sub-region.
#
# Previously, we created a correlated subquery that calculated the land area for each row. Let’s improve on that. It would be more efficient if we calculated the total land area once for each sub-region. **We can then run a query that would just retrieve the land area value from the result of the inner query.**

# %% [markdown]
# ## Connecting to our MySQL database
#
# We will use our `Geographic_location` table in our `united_nations` database that we created in MySQL Workbench. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:20!_Ke&Y@localhost:3306/united_nations

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. Calculate the total land area for each sub-region
#
# Write a query that will aggregate the data by summing the `land area` and then grouping the sums by `sub-region`. Give the sums the alias `TotalLandArea`.

# %%
# %%sql
# SELECT sub_region,
#     SUM(land_area) AS TotalLandArea
# FROM geographic_location
# GROUP BY sub_region;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 18 rows affected.
# [('Southern Asia', Decimal('4770135.41')),
#  ('Northern Africa', Decimal('6610941.00')),
#  ('Polynesia', Decimal('7217.67')),
#  ('Middle Africa', Decimal('3888270.00')),
#  ('Caribbean', Decimal('208104.00')),
#  ('South America', Decimal('15401392.00')),
#  ('Western Asia', Decimal('3488571.67')),
#  ('Australia and New Zealand', Decimal('7953710.00')),
#  ('Central America', Decimal('2452080.00')),
#  ('Western Africa', Decimal('5735548.83')),
#  ('Northern America', Decimal('9376094.00')),
#  ('Southern Africa', Decimal('2650670.00')),
#  ('South-Eastern Asia', Decimal('3865282.00')),
#  ('Eastern Africa', Decimal('5949153.16')),
#  ('Eastern Asia', Decimal('11346499.57')),
#  ('Melanesia', Decimal('529590.00')),
#  ('Micronesia', Decimal('2470.00')),
#  ('Central Asia', Decimal('3749015.17'))]

# %% [markdown]
# ### 2. Calculate country land area percentages for all the regions using a subquery in the JOIN clause
#
# Create a query with a main query that selects, from the `Geographic_location` table, the columns `Country_name`, `Land_area`, and `Sub_region`. The next line should then divide the `Land area` by the land area totals named, `TotalLandArea`, gotten from the subquery. Give this calculated column the alias `Pct_of_region_land`.
#
# The query should also have a `JOIN` clause where we will add the query we created in Exercise 1 as a subquery named `Land_per_region`. This join occurs between the `Geographic_location` table and the `Land_per_region` subquery on the `Sub_region` column.

# %%
# %%sql
# SELECT
#     g.Country_name,
#     (g.Land_area / l.TotalLandArea) * 100 AS Pct_of_region_land,
#     g.Sub_region
# FROM
#     Geographic_location g
# JOIN
#     (
#         SELECT
#             Sub_region,
#             SUM(Land_area) AS TotalLandArea
#         FROM
#             Geographic_location
#         GROUP BY
#             Sub_region
#     ) AS l
# ON
#     g.Sub_region = l.Sub_region;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# [('Sri Lanka', Decimal('1.297194'), 'Southern Asia'),
#  ('Pakistan', Decimal('16.160548'), 'Southern Asia'),
#  ('Nepal', Decimal('3.005156'), 'Southern Asia'),
#  ('Maldives', Decimal('0.006289'), 'Southern Asia'),
#  ('Iran (Islamic Republic of)', None, 'Southern Asia'),
#  ('India', Decimal('62.329258'), 'Southern Asia'),
#  ('Bhutan', Decimal('0.799506'), 'Southern Asia'),
#  ('Bangladesh', Decimal('2.728853'), 'Southern Asia'),
#  ('Afghanistan', Decimal('13.673197'), 'Southern Asia'),
#  ('Tunisia', Decimal('2.350044'), 'Northern Africa'),
#  ('Sudan', Decimal('28.256189'), 'Northern Africa'),
#  ('Morocco', Decimal('6.750930'), 'Northern Africa'),
#  ('Libya', Decimal('26.615576'), 'Northern Africa'),
#  ('Egypt', None, 'Northern Africa'),
#  ('Algeria', Decimal('36.027261'), 'Northern Africa'),
#  ('Wallis and Futuna Islands', None, 'Polynesia'),
#  ('Tuvalu', Decimal('0.415647'), 'Polynesia'),
#  ('Tonga', Decimal('9.975518'), 'Polynesia'),
#  ('Tokelau', None, 'Polynesia'),
#  ('Samoa', Decimal('38.747546'), 'Polynesia'),
#  ('Niue', None, 'Polynesia'),
#  ('French Polynesia', Decimal('48.090312'), 'Polynesia'),
#  ('Cook Islands', None, 'Polynesia'),
#  ('American Samoa', Decimal('2.770977'), 'Polynesia'),
#  ('Sao Tome and Principe', Decimal('0.024690'), 'Middle Africa'),
#  ('Gabon', Decimal('6.626855'), 'Middle Africa'),
#  ('Equatorial Guinea', Decimal('0.721401'), 'Middle Africa'),
#  ('Democratic Republic of the Congo', None, 'Middle Africa'),
#  ('Congo', None, 'Middle Africa'),
#  ('Chad', Decimal('32.384582'), 'Middle Africa'),
#  ('Central African Republic', Decimal('16.022036'), 'Middle Africa'),
#  ('Cameroon', Decimal('12.157335'), 'Middle Africa'),
#  ('Angola', Decimal('32.063103'), 'Middle Africa'),
#  ('United States Virgin Islands', None, 'Caribbean'),
#  ('Turks and Caicos Islands', Decimal('0.456503'), 'Caribbean'),
#  ('Trinidad and Tobago', Decimal('2.465114'), 'Caribbean'),
#  ('Sint Maarten (Dutch part)', Decimal('0.016338'), 'Caribbean'),
#  ('Saint Vincent and the Grenadines', None, 'Caribbean'),
#  ('Saint Martin (French Part)', None, 'Caribbean'),
#  ('Saint Lucia', None, 'Caribbean'),
#  ('Saint Kitts and Nevis', None, 'Caribbean'),
#  ('Saint Barthélemy', None, 'Caribbean'),
#  ('Puerto Rico', Decimal('4.262292'), 'Caribbean'),
#  ('Montserrat', None, 'Caribbean'),
#  ('Martinique', None, 'Caribbean'),
#  ('Jamaica', Decimal('5.204129'), 'Caribbean'),
#  ('Haiti', Decimal('13.243378'), 'Caribbean'),
#  ('Guadeloupe', None, 'Caribbean'),
#  ('Grenada', Decimal('0.163380'), 'Caribbean'),
#  ('Dominican Republic', Decimal('23.214354'), 'Caribbean'),
#  ('Dominica', Decimal('0.360397'), 'Caribbean'),
#  ('Curaçao', None, 'Caribbean'),
#  ('Cuba', Decimal('49.922154'), 'Caribbean'),
#  ('Cayman Islands', Decimal('0.115327'), 'Caribbean'),
#  ('British Virgin Islands', Decimal('0.072079'), 'Caribbean'),
#  ('Barbados', Decimal('0.206627'), 'Caribbean'),
#  ('Bahamas', None, 'Caribbean'),
#  ('Aruba', Decimal('0.086495'), 'Caribbean'),
#  ('Antigua and Barbuda', Decimal('0.211433'), 'Caribbean'),
#  ('Anguilla', None, 'Caribbean'),
#  ('Venezuela (Bolivarian Republic of)', None, 'South America'),
#  ('Uruguay', Decimal('1.136391'), 'South America'),
#  ('Suriname', Decimal('1.012895'), 'South America'),
#  ('Peru', Decimal('8.310937'), 'South America'),
#  ('Paraguay', Decimal('2.579637'), 'South America'),
#  ('Guyana', Decimal('1.278131'), 'South America'),
#  ('French Guiana', None, 'South America'),
#  ('Falkland Islands (Malvinas)', None, 'South America'),
#  ('Ecuador', Decimal('1.612582'), 'South America'),
#  ('Colombia', Decimal('7.203894'), 'South America'),
#  ('Chile', Decimal('4.827693'), 'South America'),
#  ('Brazil', Decimal('54.268731'), 'South America'),
#  ('Bolivia (Plurinational State of)', None, 'South America'),
#  ('Argentina', Decimal('17.769108'), 'South America'),
#  ('Yemen', None, 'Western Asia'),
#  ('United Arab Emirates', Decimal('2.035790'), 'Western Asia'),
#  ('Türkiye', None, 'Western Asia'),
#  ('Syrian Arab Republic', Decimal('5.263759'), 'Western Asia'),
#  ('State of Palestine', None, 'Western Asia'),
#  ('Saudi Arabia', Decimal('61.620921'), 'Western Asia'),
#  ('Qatar', Decimal('0.329361'), 'Western Asia'),
#  ('Oman', Decimal('8.871826'), 'Western Asia'),
#  ('Lebanon', Decimal('0.293243'), 'Western Asia'),
#  ('Kuwait', Decimal('0.510811'), 'Western Asia'),
#  ('Jordan', Decimal('2.545015'), 'Western Asia'),
#  ('Israel', Decimal('0.620311'), 'Western Asia'),
#  ('Iraq', Decimal('12.444291'), 'Western Asia'),
#  ('Georgia', Decimal('1.991933'), 'Western Asia'),
#  ('Cyprus', Decimal('0.264865'), 'Western Asia'),
#  ('Bahrain', Decimal('0.022383'), 'Western Asia'),
#  ('Azerbaijan', Decimal('2.369399'), 'Western Asia'),
#  ('Armenia', Decimal('0.816093'), 'Western Asia'),
#  ('New Zealand', Decimal('3.310531'), 'Australia and New Zealand'),
#  ('Australia', Decimal('96.689469'), 'Australia and New Zealand'),
#  ('Panama', Decimal('3.023963'), 'Central America'),
#  ('Nicaragua', Decimal('4.907670'), 'Central America'),
#  ('Mexico', Decimal('79.277593'), 'Central America'),
#  ('Honduras', Decimal('4.563065'), 'Central America'),
#  ('Guatemala', Decimal('4.370167'), 'Central America'),
#  ('El Salvador', Decimal('0.844997'), 'Central America'),
#  ('Costa Rica', Decimal('2.082314'), 'Central America'),
#  ('Belize', Decimal('0.930231'), 'Central America'),
#  ('Togo', Decimal('0.948296'), 'Western Africa'),
#  ('Sierra Leone', Decimal('1.258467'), 'Western Africa'),
#  ('Senegal', Decimal('3.356784'), 'Western Africa'),
#  ('Saint Helena', None, 'Western Africa'),
#  ('Nigeria', Decimal('15.879387'), 'Western Africa'),
#  ('Niger', Decimal('22.085070'), 'Western Africa'),
#  ('Mauritania', Decimal('17.970381'), 'Western Africa'),
#  ('Mali', Decimal('21.274163'), 'Western Africa'),
#  ('Liberia', Decimal('1.679351'), 'Western Africa'),
#  ('Guinea-Bissau', Decimal('0.490276'), 'Western Africa'),
#  ('Guinea', Decimal('4.284158'), 'Western Africa'),
#  ('Ghana', Decimal('3.967168'), 'Western Africa'),
#  ('Gambia', None, 'Western Africa'),
#  ("Côte d'Ivoire", None, 'Western Africa'),
#  ('Cabo Verde', Decimal('0.070264'), 'Western Africa'),
#  ('Burkina Faso', Decimal('4.770250'), 'Western Africa'),
#  ('Benin', Decimal('1.965984'), 'Western Africa'),
#  ('United States of America', None, 'Northern America'),
#  ('Saint Pierre and Miquelon', None, 'Northern America'),
#  ('Greenland', Decimal('4.377622'), 'Northern America'),
#  ('Canada', Decimal('95.621802'), 'Northern America'),
#  ('Bermuda', Decimal('0.000576'), 'Northern America'),
#  ('South Africa', Decimal('45.765410'), 'Southern Africa'),
#  ('Namibia', Decimal('31.059694'), 'Southern Africa'),
#  ('Lesotho', Decimal('1.145371'), 'Southern Africa'),
#  ('Eswatini', Decimal('0.648893'), 'Southern Africa'),
#  ('Botswana', Decimal('21.380632'), 'Southern Africa'),
#  ('Viet Nam', None, 'South-Eastern Asia'),
#  ('Timor-Leste', Decimal('0.384707'), 'South-Eastern Asia'),
#  ('Thailand', Decimal('13.217406'), 'South-Eastern Asia'),
#  ('Singapore', Decimal('0.018446'), 'South-Eastern Asia'),
#  ('Philippines', Decimal('7.714056'), 'South-Eastern Asia'),
#  ('Myanmar', Decimal('16.888289'), 'South-Eastern Asia'),
#  ('Malaysia', Decimal('8.500027'), 'South-Eastern Asia'),
#  ("Lao People's Democratic Republic", None, 'South-Eastern Asia'),
#  ('Indonesia', Decimal('48.573920'), 'South-Eastern Asia'),
#  ('Cambodia', Decimal('4.566808'), 'South-Eastern Asia'),
#  ('Brunei Darussalam', Decimal('0.136342'), 'South-Eastern Asia'),
#  ('Zimbabwe', Decimal('6.502606'), 'Eastern Africa'),
#  ('Zambia', Decimal('12.495728'), 'Eastern Africa'),
#  ('United Republic of Tanzania', None, 'Eastern Africa'),
#  ('Uganda', Decimal('3.370564'), 'Eastern Africa'),
#  ('South Sudan', Decimal('10.622184'), 'Eastern Africa'),
#  ('Somalia', Decimal('10.545030'), 'Eastern Africa'),
#  ('Seychelles', Decimal('0.007732'), 'Eastern Africa'),
#  ('Rwanda', Decimal('0.414681'), 'Eastern Africa'),
#  ('Réunion', None, 'Eastern Africa'),
#  ('Mozambique', Decimal('13.218352'), 'Eastern Africa'),
#  ('Mayotte', None, 'Eastern Africa'),
#  ('Mauritius', Decimal('0.034123'), 'Eastern Africa'),
#  ('Malawi', Decimal('1.584763'), 'Eastern Africa'),
#  ('Madagascar', Decimal('9.779543'), 'Eastern Africa'),
#  ('Kenya', Decimal('9.566740'), 'Eastern Africa'),
#  ('Ethiopia', Decimal('18.970079'), 'Eastern Africa'),
#  ('Eritrea', Decimal('2.035300'), 'Eastern Africa'),
#  ('Djibouti', Decimal('0.389635'), 'Eastern Africa'),
#  ('Comoros', Decimal('0.031282'), 'Eastern Africa'),
#  ('Burundi', Decimal('0.431658'), 'Eastern Africa'),
#  ('Republic of Korea', None, 'Eastern Asia'),
#  ('Mongolia', Decimal('13.724917'), 'Eastern Asia'),
#  ('Japan', Decimal('3.212444'), 'Eastern Asia'),
#  ("Democratic People's Republic of Korea", None, 'Eastern Asia'),
#  ('China', Decimal('83.062638'), 'Eastern Asia'),
#  ('Vanuatu', Decimal('2.301781'), 'Melanesia'),
#  ('Solomon Islands', Decimal('5.285221'), 'Melanesia'),
#  ('Papua New Guinea', Decimal('85.511433'), 'Melanesia'),
#  ('New Caledonia', Decimal('3.451727'), 'Melanesia'),
#  ('Fiji', Decimal('3.449839'), 'Melanesia'),
#  ('Palau', Decimal('18.623482'), 'Micronesia'),
#  ('Northern Mariana Islands', Decimal('18.623482'), 'Micronesia'),
#  ('Nauru', Decimal('0.809717'), 'Micronesia'),
#  ('Micronesia (Federated States of)', None, 'Micronesia'),
#  ('Marshall Islands', Decimal('7.287449'), 'Micronesia'),
#  ('Kiribati', Decimal('32.793522'), 'Micronesia'),
#  ('Guam', Decimal('21.862348'), 'Micronesia'),
#  ('Uzbekistan', Decimal('11.752291'), 'Central Asia'),
#  ('Turkmenistan', Decimal('12.534759'), 'Central Asia'),
#  ('Tajikistan', Decimal('3.702039'), 'Central Asia'),
#  ('Kyrgyzstan', None, 'Central Asia'),
#  ('Kazakhstan', Decimal('72.010912'), 'Central Asia')]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Calculate the total land area for each sub-region

# %%
# %%sql
#
# SELECT
#     Sub_region,
#     SUM(Land_area) AS Total_Land_Area
# FROM
#     Geographic_location
# GROUP BY
#     Sub_region

# %% [markdown]
# This gives us a table with a list of all the sub-regions and their total land areas calculated. In this case, we are not calculating a single value, but an entire table of values. Now we just join this table to the main one and reference the `Sub-region` as the key.

# %% [markdown]
# ### 2. Calculate country land area percentages for all the regions using a subquery in the JOIN clause

# %%
# %%sql
#
# SELECT
#     geoloc.Country_name,
#     geoloc.Land_area,
#     geoloc.Sub_region,
#     (geoloc.Land_area / Land_per_region.Total_Land_Area) * 100 AS Pct_Of_Region_Land
# FROM
#     Geographic_location AS geoloc
# JOIN
#     (
#     SELECT
#         Sub_region,
#         SUM(Land_area) AS Total_Land_Area
#     FROM
#         Geographic_location
#     GROUP BY
#         Sub_region)  AS Land_per_region
#     ON
#         geoloc.Sub_region = Land_per_region.sub_Region;

# %% [markdown]
# While this method may look a bit more complicated, it runs much faster than the previous method because it does not need to repeat calculations for each row. This is especially true for larger tables.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
